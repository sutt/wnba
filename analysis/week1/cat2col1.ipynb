# %%
import sys, numpy as np, sklearn, pandas as pd
import os, pickle
sys.path.append('../../pkg/')
# %load_ext autoreload

# %%
# %aimport cat

# %%
pick_dir = '../../data/pickle/test2/'
os.mkdir(pick_dir)

# %%
inp = '../../data/main/train_100/training_1.csv'
out = '../../data/main/cat1/cat1.csv'

# %%
rd = cat.Cats.cat_dict(15,inp,pick_dir)

# %%
# %autoreload 2
cat.Cats.mic_check()
# Out:
# 'no print'

# %%
out = '../../data/main/cat1/mycat.csv'
cat.Cats.score_cat(inp,out,pick_dir,**{'cat_cols':[15],'skip_rows':1})
# Out:
# [15]
# 1

# %%
mycat = pd.read_csv(out)

# %%
mycat
# Out:
#           Id  Label  I1    I2   I3  I4      I5   I6   I7  I8   I9  I10  I11  \
# 0   10000199      0 NaN    19   32   0    1994  NaN    0  19   26  NaN    0
# 1   10000299      0 NaN     7   32  23   31645   41   15  14   24  NaN    0
# 2   10000399      1 NaN    -1  NaN NaN   23456   33    3   0   21  NaN    1
# 3   10000499      0   0     0    6   1    2913   61    4  10   35    0    1
# 4   10000599      0   0   305    1   1    1974  132    9  29  137    0    4
# 5   10000699      0 NaN     1    1   2   16125   77    1  11   73  NaN    1
# 6   10000799      0   0    85    1  30    4291  116   11  39   96    0    2
# 7   10000899      1  24   597  NaN   5      56    6   24   5    6    1    1
# 8   10000999      0   0     1    1   1    8647  NaN    0   9    1    0    0
# 9   10001099      1   2    56  NaN   1       1    1    2   1    1    1    1
# 10  10001199      1  10   122    2   2      54    3  166  11  174    1   15
# ...
