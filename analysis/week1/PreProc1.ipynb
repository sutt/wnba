# %%
import sys, numpy as np, sklearn, pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
sys.path.append('../../pkg/')
from err import Err
from xplot import MyPlot

# %%
df = np.genfromtxt('../../data/main/train_100/training_1.csv' \
                   ,skiprows = 1 \
                   ,delimiter = ','
                   ,usecols = range(0,15))

# %%
pddf = pd.DataFrame(df)

# %%
pddf.describe().T
# Out:
#      count             mean              std       min       25%       50%  \
# 0   458406  32920349.000000  13233055.808656  10000099  21460224  32920349
# 1   458406         0.255778         0.436298         0         0         0
# 2   250146         3.484689         9.037674         0         0         1
# 3   458406       105.676662       389.642699        -3         0         3
# 4   359840        27.369392       420.150017         0         2         6
# 5   358705         7.351526         8.920355         0         2         4
# 6   446701     18603.347736     69501.909267         0       331      2816
# 7   355612       114.585003       310.493132         0         8        33
# 8   438482        16.249905        65.428415         0         1         3
# 9   458156        12.524566        16.114029         0         2         7
# 10  438482       105.519296       220.130489         0        10        38
# ...

# %%
from sklearn.preprocessing import Imputer
import sklearn
from sklearn import linear_model

# %%
imp = Imputer(missing_values='NaN',strategy = 'mean')

# %%
imp.fit(pddf)
impdf = imp.transform(pddf)

# %%
pd.DataFrame(impdf).describe().T
# Out:
#      count             mean              std       min              25%  \
# 0   458406  32920349.000000  13233055.808656  10000099  21460224.000000
# 1   458406         0.255778         0.436298         0         0.000000
# 2   458406         3.484689         6.676178         0         1.000000
# 3   458406       105.676662       389.642699        -3         0.000000
# 4   458406        27.369392       372.249247         0         3.000000
# 5   458406         7.351526         7.890883         0         2.000000
# 6   458406     18603.347736     68608.833963         0       375.000000
# 7   458406       114.585003       273.473292         0        13.000000
# 8   458406        16.249905        63.990737         0         1.000000
# 9   458406        12.524566        16.109635         0         2.000000
# 10  458406       105.519296       215.293498         0        11.000000
# 11  458406         0.617947         0.505267         0         0.000000
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#plt.hist(impdf[['3']])
#pd.DataFrame(impdf).iloc[:,[3]]
plt.hist(pd.DataFrame(impdf)[3])
# Out:
# (array([  4.4888e+05,   6.6910e+03,   2.5970e+03,   1.4000e+02,
#           5.4000e+01,   2.5000e+01,   6.0000e+00,   4.0000e+00,
#           5.0000e+00,   3.0000e+00]),
#  array([ -3.0000e+00,   1.3688e+03,   2.7406e+03,   4.1124e+03,
#           5.4842e+03,   6.8560e+03,   8.2278e+03,   9.5996e+03,
#           1.0971e+04,   1.2343e+04,   1.3715e+04]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import preprocessing

# %%
sscal = preprocessing.StandardScaler().fit(impdf)
ssdf = sscal.transform(impdf)
ssdf = sscal.transform(impdf)

# %%
#ssdf[2]
plt.hist(ssdf[2], bins= 30)
plt.show()
plt.hist(ssdf[10], bins= 30)
plt.show()

# %%
scal = preprocessing.Scaler().fit(impdf)
sdf = scal.transform(impdf)
sdf = scal.transform(impdf)
plt.hist(sdf[2], bins= 30)
plt.show()
plt.hist(sdf[10], bins= 30)
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\data.py:393: DeprecationWarning: Scaler was renamed to StandardScaler. The old name  will be removed in 0.15.
#   " will be removed in 0.15.", DeprecationWarning)

# %%
from math import log
log(1)
# Out:
# 0.0000

# %%
log(np.nan_to_num())

# %%
df[:,2]
# Out:
# array([  0.,  nan,  nan, ...,  nan,  nan,  nan])

# %%
logx2 = np.apply_along_axis( lambda x: log( min(1,1+np.nan_to_num(x)) ), arr = df[:,2:3] , axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-a3e0dfd6cdd7> in <module>()
# ----> 1 logx2 = np.apply_along_axis( lambda x: log( min(1,1+np.nan_to_num(x)) ), arr = df[:,2:3] , axis = 0)
#
# C:\Anaconda\lib\site-packages\numpy\lib\shape_base.pyc in apply_along_axis(func1d, axis, arr, *args)
#      77     outshape = asarray(arr.shape).take(indlist)
#      78     i.put(indlist, ind)
# ---> 79     res = func1d(arr[tuple(i.tolist())],*args)
#      80     #  if res is a number, then we have a smaller output array
#      81     if isscalar(res):
#
# <ipython-input-124-a3e0dfd6cdd7> in <lambda>(x)
# ----> 1 logx2 = np.apply_along_axis( lambda x: log( min(1,1+np.nan_to_num(x)) ), arr = df[:,2:3] , axis = 0)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
for in i range
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-cd81baccc4e7> in <module>()
#       1 from math import log
# ----> 2 logdf = np.apply_along_axis(lambda x: log(x), axis=1, arr = impdf)
#
# C:\Anaconda\lib\site-packages\numpy\lib\shape_base.pyc in apply_along_axis(func1d, axis, arr, *args)
#      77     outshape = asarray(arr.shape).take(indlist)
#      78     i.put(indlist, ind)
# ---> 79     res = func1d(arr[tuple(i.tolist())],*args)
#      80     #  if res is a number, then we have a smaller output array
#      81     if isscalar(res):
#
# <ipython-input-76-cd81baccc4e7> in <lambda>(x)
#       1 from math import log
# ----> 2 logdf = np.apply_along_axis(lambda x: log(x), axis=1, arr = impdf)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
myplot.MyPlot.all_hist(pddf, range(2,15))

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from xplot import MyPlot

# %%
# %aimport myplot

# %%
myplot.MyPlot.miccheck()
# Out:
# '1,2,3'

# %%
reload(myplot)
# Out:
# <module 'myplot' from '../../pkg/myplot.pyc'>

# %%
MyPlot.miccheck()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-fda0dcf9fcc5> in <module>()
# ----> 1 MyPlot.miccheck()
#
# AttributeError: class MyPlot has no attribute 'miccheck'

# %%
MyPlot.all_hist(pddf,[2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-a43391d50692> in <module>()
# ----> 1 MyPlot.all_hist(pddf,[2,3,4,5])
#
# C:\Users\wsutt_000\Desktop\wnba\pkg\xplot.py in all_hist(df, col_list)
#      19                         col = col_list[i]
#      20                         vals = filter( lambda x: x == x, df[col] )
# ---> 21                         mid = np.mean(vals)
#      22                         centers = filter( lambda x: (x < (mid*max_x)),vals )
#      23                         bins = mid*max_x if mid*max_x < 30 else 30
#
# NameError: global name 'np' is not defined

# %%
# Out:
# 0      0
# 1    NaN
# 2    NaN
# 3    NaN
# 4      0
# 5      0
# 6    NaN
# 7      0
# 8     24
# 9      0
# 10     2
# 11    10
# 12     5
# 13     3
# 14     0
# ...
# 458391     0
# 458392   NaN
# 458393   NaN
# 458394     2
# 458395     1
# 458396     0
# 458397   NaN
# 458398     5
# 458399   NaN
# 458400   NaN
# 458401     0
# 458402   NaN
# 458403   NaN
# 458404   NaN
# 458405   NaN
# Name: 2, Length: 458406, dtype: float64

# %%
float(m * (float(1)-m))
# Out:
# 0.1924

# %%
.1924 ** .5
# Out:
# 0.4386

# %%
pd
